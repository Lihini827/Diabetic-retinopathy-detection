# %% [markdown]
# <a href="https://colab.research.google.com/github/Lihini827/Diabetic-retinopathy-detection/blob/main/AutoCropping(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/test/Mild'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/07a1c7073982.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/01b3aed3ed4c.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/4da2961e62fe.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/4dd9d29eae5d.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/4c3c1ed09771.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/5cab3ef4b31c.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/5777ef74c9ec.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/7005be54cab1.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/Mild/b8ebedd382de.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/test/Moderate'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate/0180bfa26c0b.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate/08752092140d.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate/1414128bead0.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate/032d7b0b4bf6.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate/34723fae6475.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate/367c7049929c.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate/2cceb07ff706.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Moderate/37de05ef12a5.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/test/No_DR'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/38f1901f214a.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/3232b34cbe99.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/4ad8d3ec8789.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/4a4cb731f91a.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/44878f34e31f.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/43823561c3f0.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/496155f71d0a.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/454a944eb557.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/No_DR/4a05f81b3aba.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/test/Proliferate_DR'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR/499c8df39222.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR/0e0fc1d9810c.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR/25d069089c5e.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR/0981195eb9fb.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR/281d7b7c7676.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR/62318d514160.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR/5d74f98d62be.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Proliferate_DR/710b05a96e0f.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/test/Severe'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe/4fecf87184e6.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe/90b8bf342032.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe/996f57c86ba5.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe/dbb2c63f6f08.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe/e1fb532f55df.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe/e93394175a19.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe/457c7c927e27.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/test/Severe/498f143c0374.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/train/Mild'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/0fb1053285cf.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/0a61bddab956.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/18b06f56ab27.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/0f495d87656a.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/4dd5d5ccddcf.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/278aa860dffd.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/4e6071b73120.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/35d6c4c50072.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Mild/4661006f3ba6.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/train/Moderate'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Moderate'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Moderate/0augmented_bca2bdc15fc5.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Moderate/0augmented_bcc762618e7d.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Moderate/0augmented_ad570b850a4f.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Moderate/0augmented_bb733062f494.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Moderate/0augmented_bdb98063fe84.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Moderate/0augmented_c252da9b41d8.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Moderate/0augmented_c1c8550508e0.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/train/No_DR'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR/ec57cc20d776.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR/1augmented_74211a2b6dcf.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR/1augmented_70d0392397de.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR/1augmented_6e0f78e188ff.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR/1augmented_6b3860e8f64f.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR/1augmented_6bf2a81a5d91.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR/1augmented_6e018411ba4a.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/No_DR/1augmented_6c6505a0c637.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/train/Proliferate_DR'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR/2df07eb5779f.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR/3206171db5be.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR/312694ea8e6a.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR/15e96e848b46.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR/0e82bcacc475.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR/0ada12c0e78f.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR/3ca637fddd56.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Proliferate_DR/51af8c112682.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/train/Severe'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe/093a42649c29.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe/1c9521878baf.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe/4c60b10a3a6a.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe/269b44e628eb.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe/03c85870824c.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe/42cc993f23a9.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe/6061f5b7378d.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/train/Severe/36b5b3c9fb32.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/val/Mild'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/086d41d17da8.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/0a3202889f4d.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/194814669fee.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/365f8c01d994.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/76e589911303.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/58ccba7eec9c.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/7427dedafccf.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/7ccb267fd394.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Mild/ad1f7445b1a8.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/val/Moderate'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate/13d71389563f.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate/1ae8c165fd53.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate/224bb938e2dd.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate/18d8fdb140b7.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate/18f1f979d30d.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate/1541226c5d72.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate/1968183f0e61.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Moderate/261c6bd63bff.png
# ...

# %% [markdown]
# didn't run

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/val/No_DR'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/4a5a6efc0bef.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/4134b290f5f3.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/3d2ecffe0386.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/3f6c627e2ff2.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/42af7282349b.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/4464bb62bf20.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/5321ab64f9ea.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/5069feccd866.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/No_DR/55968f0e63c4.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/val/Proliferate_DR'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR/26463a5fb949.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR/0ceb222f6629.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR/46cdc8b685bd.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR/08a3875063c3.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR/3810040096cb.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR/8db2ce991101.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR/63b4d030b016.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Proliferate_DR/bd5013540a13.png
# ...

# %%
import cv2
import numpy as np
import os

def auto_crop(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to segment out the black areas
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through the contours and find the largest one
    max_contour = None
    max_area = 0
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > max_area:
            max_contour = contour
            max_area = area

    # Crop the image using the largest contour
    x, y, w, h = cv2.boundingRect(max_contour)
    cropped_image = image[y:y+h, x:x+w]

    return cropped_image

# Set input and output folders
input_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Ben/val/Severe'
output_folder = '/content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through all images in the input folder
for filename in os.listdir(input_folder):
    # Load the image
    image_path = os.path.join(input_folder, filename)
    image = cv2.imread(image_path)

    # Auto crop the image
    cropped_image = auto_crop(image)

    # Save the cropped image to the output folder
    output_path = os.path.join(output_folder, filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/07a0e34c8d20.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/25b0e72705a8.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/1b495ac025b7.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/0c917c372572.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/c31651ea04c6.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/910bfd38e2f5.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/7525ebb3434d.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/d2ffe9287dc7.png
# Cropped image saved to /content/drive/MyDrive/DiabticRetinopathy/Preprocess/Auto/val/Severe/c3a82acb7d7a.png
# ...
